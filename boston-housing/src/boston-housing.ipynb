# %% [markdown]
# The Boston Housing Dataset
#
# The Boston Housing Dataset is a derived from information collected by the U.S. Census Service concerning housing in the area of Boston MA. The following describes the dataset columns:
#
# * CRIM - per capita crime rate by town
# * ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# * INDUS - proportion of non-retail business acres per town.
# * CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# * NOX - nitric oxides concentration (parts per 10 million)
# * RM - average number of rooms per dwelling
# * AGE - proportion of owner-occupied units built prior to 1940
# * DIS - weighted distances to five Boston employment centres
# * RAD - index of accessibility to radial highways
# * TAX - full-value property-tax rate per \$10,000
# * PTRATIO - pupil-teacher ratio by town
# * B - 1000x(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# * LSTAT - \% lower status of the population
# * MEDV - Median value of owner-occupied homes in \$1000's

# %% [markdown]
# Importing required libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import sagemaker

# %% [markdown]
# # Preparing data

# %% [markdown]
# Loading the csv dataset

# %%
dataset = pd.read_csv('../data/HousingData.csv')

# %%
dataset.shape
# Out:
# (506, 14)

# %%
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
dataset.dtypes
# Out:
# MEDV       float64
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# dtype: object

# %%
dataset.isna().sum()
# Out:
# MEDV        0
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# dtype: int64

# %%
dataset.loc[dataset['CRIM'].isna() == True]
# Out:
#      MEDV  CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 53   23.4   NaN  21.0   5.64   0.0  0.439  5.998   21.4  6.8147    4  243
# 115  18.3   NaN   0.0  10.01   0.0  0.547  5.928   88.2  2.4631    6  432
# 183  32.5   NaN   0.0   2.46   0.0  0.488  6.563   95.6  2.8470    3  193
# 191  30.5   NaN  45.0   3.44   0.0  0.437  6.739   30.8  6.4798    5  398
# 192  36.4   NaN  45.0   3.44   0.0  0.437  7.178   26.3  6.4798    5  398
# 196  33.3   NaN  80.0   1.52   0.0  0.404  7.287   34.1  7.3090    2  329
# 229  31.5   NaN   0.0   6.20   0.0  0.504  6.552   21.4  3.3751    8  307
# 236  25.1   NaN   0.0   6.20   1.0  0.507  6.631   76.5  4.1480    8  307
# 241  20.1   NaN  30.0   4.93   0.0  0.428  6.095   65.1  6.3361    6  300
# 262  48.8   NaN  20.0   3.97   0.0  0.647  8.398   91.5  2.2885    5  264
# 288  22.3   NaN  52.5   5.32   0.0  0.405  6.315   45.6  7.3172    6  293
# 302  26.4   NaN  34.0   6.09   0.0  0.433  6.495   18.4  5.4917    7  329
# 369  50.0   NaN   0.0  18.10   1.0  0.631  6.683   96.8  1.3567   24  666
# 393  13.8   NaN   0.0  18.10   0.0  0.693  6.193   92.6  1.7912   24  666
# 394  12.7   NaN   0.0  18.10   0.0  0.693  5.887   94.7  1.7821   24  666
# 409  27.5   NaN   0.0  18.10   0.0  0.597  6.852  100.0  1.4655   24  666
# 426  10.2   NaN   0.0  18.10   0.0  0.584  5.837   59.7  1.9976   24  666
# 430  14.5   NaN   0.0  18.10   0.0  0.584  6.348   86.1  2.0527   24  666
# 460  16.4   NaN   0.0  18.10   0.0  0.713  6.701   90.0  2.5975   24  666
# 465  19.9   NaN   0.0  18.10   NaN  0.655  5.759   48.2  3.0665   24  666
#
#      PTRATIO       B  LSTAT
# 53      16.8  396.90   8.43
# 115     17.8  344.91  15.76
# 183     17.8  396.90   5.68
# 191     15.2  389.71   4.69
# 192     15.2  390.49   2.87
# 196     12.6  396.90   4.08
# 229     17.4  380.34   3.76
# 236     17.4  388.45   9.54
# 241     16.6  394.62  12.40
# 262     13.0  386.86   5.91
# 288     16.6  396.90   7.60
# 302     16.1  383.61   8.67
# 369     20.2  375.33   3.73
# 393     20.2  396.90  15.17
# 394     20.2  396.90  16.35
# 409     20.2  179.36  19.78
# 426     20.2   24.65  15.69
# 430     20.2   83.45  17.64
# 460     20.2  255.23  16.42
# 465     20.2  334.40  14.13

# %%
dataset = dataset.fillna(0.0)

# %%
dataset.isna().sum()
# Out:
# MEDV       0
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %% [markdown]
# Amazon SageMaker requires that a csv file doesn't have a header record and that the target variable is in first column

# %%
dataset = pd.concat([dataset['MEDV'], dataset.drop(['MEDV'], axis=1)], axis=1)

# %% [markdown]
# Checking if 'MEDV' column has been moved to first position

# %%
dataset.head()
# Out:
#    MEDV     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0  24.0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1  21.6  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2  34.7  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3  33.4  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4  36.2  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90    NaN

# %% [markdown]
# Splitting the dataframe up into two parts - 90% for training, and 10% for validation

# %%
training_dataset, validation_dataset = train_test_split(dataset, test_size=0.1, random_state=12345)

# %% [markdown]
# Save these two splits to individual CSV files, without either an index or a header

# %%
training_dataset.to_csv('../data/training_dataset.csv', index=False, header=False)
validation_dataset.to_csv('../data/validation_dataset.csv', index=False, header=False)

# %% [markdown]
# Uploading these two files to S3 using default bucket created by SageMaker in the region we're running in.

# %%
sess = sagemaker.Session()
bucket = sess.default_bucket()

# %%
bucket
# Out:
# 'sagemaker-eu-central-1-065391449321'

# %%
prefix = 'boston-housing'

training_data_path = sess.upload_data(
    path='../data/training_dataset.csv',
    key_prefix=prefix+'/input/training'
)

validation_data_path = sess.upload_data(
    path='../data/validation_dataset.csv',
    key_prefix=prefix+'/input/validation'
)

# %%
print(training_data_path)
print(validation_data_path)
# Out:
# s3://sagemaker-eu-central-1-065391449321/boston-housing/input/training/training_dataset.csv
# s3://sagemaker-eu-central-1-065391449321/boston-housing/input/validation/validation_dataset.csv

# %% [markdown]
# # Configuring a training job

# %%
from sagemaker import get_execution_role
from sagemaker.image_uris import retrieve
from sagemaker.estimator import Estimator
from sagemaker import TrainingInput

# %% [markdown]
# SageMaker algorithms are packed in Docker containers.
# Using boto3 and the image_uris.retrieve() it's easy to find the name of the Linear Learner algorithm in the region we're running.

# %%
region = sess.boto_session.region_name
container = retrieve('linear-learner', region)

# %%
print(region)
print(container)
# Out:
# eu-central-1
# 664544806723.dkr.ecr.eu-central-1.amazonaws.com/linear-learner:1

# %% [markdown]
# Configuring training job with Estimator object.

# %%
ll_estimator = Estimator(
    container, # container name
    role=get_execution_role(), # IAM role that SageMaker instances will use
    instance_count=1, # number of instances used for training
    instance_type='ml.m4.2xlarge', # type of instances used for training
    use_spot_instances=True, # use spot instances (cheaper)
    max_run = (1 * 60 * 60),
    max_wait = (1 * 60 * 60),
    output_path=f's3://{bucket}/{prefix}/output' # output path for the model
)

# %% [markdown]
# Setting hyperparameters.
# Only one hyperparameter is mandatory, the rest can be set by default.
# normalize_data parameter is set to true by default, so it is unnecessary to normalize data ourselves.
# Default value for mini_batch_size parameter is 1000, for dataset with 506-sample dataset this isn't going to work well - so we change this to 32.

# %%
ll_estimator.set_hyperparameters(
    predictor_type='regressor',
    mini_batch_size=32
)

# %% [markdown]
# Defining the data channels: channel is a named source of data passed to a SageMaker estimator.
# All built-in algorithms need at least a training channel, and many also accept validation and testing channels.

# %%
training_data_channel = TrainingInput(
    s3_data=training_data_path,
    content_type='text/csv'
)

validation_data_channel = TrainingInput(
    s3_data=validation_data_path,
    content_type='text/csv'
)

# %% [markdown]
# # Launching a training job

# %%
ll_estimator.fit(
    {
        'train': training_data_channel,
        'validation': validation_data_channel
    }
)
# Out:
# 2022-10-21 20:42:03 Starting - Starting the training job...
# 2022-10-21 20:42:26 Starting - Preparing the instances for trainingProfilerReport-1666384923: InProgress
# ............
# 2022-10-21 20:44:33 Downloading - Downloading input data
# 2022-10-21 20:44:33 Training - Downloading the training image...............
# 2022-10-21 20:46:54 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [10/21/2022 20:46:57 INFO 140694817969984] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [10/21/2022 20:46:57 INFO 140694817969984] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'mini_batch_size': '32', 'predictor_type': 'regressor'}
# [10/21/2022 20:46:57 INFO 140694817969984] Final configuration: {'mini_batch_size': '32', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [10/21/2022 20:47:01 WARNING 140694817969984] Loggers have already been setup.
# [10/21/2022 20:47:01 INFO 140694817969984] Final configuration: {'mini_batch_size': '32', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [10/21/2022 20:47:01 WARNING 140694817969984] Loggers have already been setup.
# Process 1 is a worker.
# [10/21/2022 20:47:01 INFO 140694817969984] Using default worker.
# [10/21/2022 20:47:01 INFO 140694817969984] Checkpoint loading and saving are disabled.
# [10/21/2022 20:47:01 INFO 140694817969984] Create Store: local
# [10/21/2022 20:47:01 INFO 140694817969984] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7ff580e19d10>
# [10/21/2022 20:47:01 INFO 140694817969984] Scaling model computed with parameters:
#  {'stdev_label':
# [9.534204]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [8.60737324e+00 2.23093224e+01 7.07236814e+00 2.57539332e-01
#  1.16248846e-01 7.13009953e-01 3.04542961e+01 2.06468773e+00
#  8.61687469e+00 1.68406769e+02 2.16069794e+00 8.79873123e+01
#  7.53832626e+00]
# <NDArray 13 @cpu(0)>, 'mean_label':
# [22.709148]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [3.4314709e+00 1.0302456e+01 1.0625691e+01 7.1428567e-02 5.5552614e-01
#  6.3024178e+00 6.6104462e+01 3.7616301e+00 9.3683043e+00 4.0384824e+02
#  1.8448662e+01 3.5910196e+02 1.2224844e+01]
# <NDArray 13 @cpu(0)>}
# [10/21/2022 20:47:01 INFO 140694817969984] nvidia-smi: took 0.034 seconds to run.
# [10/21/2022 20:47:01 INFO 140694817969984] nvidia-smi identified 0 GPUs.
# [10/21/2022 20:47:01 INFO 140694817969984] Number of GPUs being used: 0
# #metrics {"StartTime": 1666385222.0008764, "EndTime": 1666385222.0009372, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum":
"Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.4905004895159176, "count": 1, "min": 0.4905004895159176, "max": 0.4905004895159176}}}
# #metrics {"StartTime": 1666385222.8477619, "EndTime": 1666385222.8477728, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.38523119368723463, "count": 1, "min": 0.38523119368723463, "max": 0.38523119368723463}}}
# #metrics {"StartTime": 1666385222.8478117, "EndTime": 1666385222.847821, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.37442744470068384, "count": 1, "min": 0.37442744470068384, "max": 0.37442744470068384}}}
# #metrics {"StartTime": 1666385222.847853, "EndTime": 1666385222.8478613, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.38466511347464155, "count": 1, "min": 0.38466511347464155, "max": 0.38466511347464155}}}
# #metrics {"StartTime": 1666385222.847897, "EndTime": 1666385222.8479116, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.38782888863767895, "count": 1, "min": 0.38782888863767895, "max": 0.38782888863767895}}}
# #metrics {"StartTime": 1666385222.8479657, "EndTime": 1666385222.847977, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.547266981431416, "count": 1, "min": 0.547266981431416, "max": 0.547266981431416}}}
# #metrics {"StartTime": 1666385222.848028, "EndTime": 1666385222.8480437, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.6169585053409848, "count": 1, "min": 0.6169585053409848, "max": 0.6169585053409848}}}
# #metrics {"StartTime": 1666385222.8481054, "EndTime": 1666385222.8481221, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.5116381464259965, "count": 1, "min": 0.5116381464259965, "max": 0.5116381464259965}}}
# #metrics {"StartTime": 1666385222.8481808, "EndTime": 1666385222.848191, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.5663600979106767, "count": 1, "min": 0.5663600979106767, "max": 0.5663600979106767}}}
# #metrics {"StartTime": 1666385222.848243, "EndTime": 1666385222.848259, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.3862663805484772, "count": 1, "min": 0.3862663805484772, "max": 0.3862663805484772}}}
# #metrics {"StartTime": 1666385222.8483138, "EndTime": 1666385222.8483307, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.3871732567037855, "count": 1, "min": 0.3871732567037855, "max": 0.3871732567037855}}}
# #metrics {"StartTime": 1666385222.8483958, "EndTime": 1666385222.848414, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.3932827061840466, "count": 1, "min": 0.3932827061840466, "max": 0.3932827061840466}}}
# #metrics {"StartTime": 1666385222.8484797, "EndTime": 1666385222.8484986, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.38032369847808567, "count": 1, "min": 0.38032369847808567, "max": 0.38032369847808567}}}
# #metrics {"StartTime": 1666385222.8485644, "EndTime": 1666385222.848583, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.5487309651715415, "count": 1, "min": 0.5487309651715415, "max": 0.5487309651715415}}}
# #metrics {"StartTime": 1666385222.8486457, "EndTime": 1666385222.8486638, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.49550701464925495, "count": 1, "min": 0.49550701464925495, "max": 0.49550701464925495}}}
# #metrics {"StartTime": 1666385222.848729, "EndTime": 1666385222.8487473, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.6457696173872266, "count": 1, "min": 0.6457696173872266, "max": 0.6457696173872266}}}
# #metrics {"StartTime": 1666385222.848804, "EndTime": 1666385222.848816, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.5554854603750365, "count": 1, "min": 0.5554854603750365, "max": 0.5554854603750365}}}
# #metrics {"StartTime": 1666385222.8488667, "EndTime": 1666385222.8488827, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.4812930492418153, "count": 1, "min": 0.4812930492418153, "max": 0.4812930492418153}}}
# #metrics {"StartTime": 1666385222.8489454, "EndTime": 1666385222.8489587, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.46034842623131617, "count": 1, "min": 0.46034842623131617, "max": 0.46034842623131617}}}
# #metrics {"StartTime": 1666385222.8490217, "EndTime": 1666385222.8490393, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0
{"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Max Batches Seen Between Resets": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Reset Count": {"sum": 10.0, "count": 1, "min": 10, "max": 10}, "Number of Records Since Last Reset": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Number of Batches Since Last Reset": {"sum": 15.0, "count": 1, "min": 15, "max": 15}}}
# [10/21/2022 20:47:06 INFO 140694817969984] #throughput_metric: host=algo-1, train throughput=952.7783272332954 records/second
# [10/21/2022 20:47:06 WARNING 140694817969984] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [10/21/2022 20:47:06 WARNING 140694817969984] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [10/21/2022 20:47:06 INFO 140694817969984] #early_stopping_criteria_metric: host=algo-1, epoch=7, criteria=mse_objective, value=16.685549866919423
# [10/21/2022 20:47:06 INFO 140694817969984] #validation_score (algo-1) : ('mse_objective', 15.869095147824755)
# [10/21/2022 20:47:06 INFO 140694817969984] #validation_score (algo-1) : ('mse', 15.869095147824755)
# [10/21/2022 20:47:06 INFO 140694817969984] #validation_score (algo-1) : ('absolute_loss', 3.1916581696155024)
# [10/21/2022 20:47:06 INFO 140694817969984] #validation_score (algo-1) : ('rmse', 3.9836032869532523)
# [10/21/2022 20:47:06 INFO 140694817969984] #validation_score (algo-1) : ('r2', 0.4635006141808501)
# [10/21/2022 20:47:06 INFO 140694817969984] #validation_score (algo-1) : ('mae', 3.1916581135170135)
# [10/21/2022 20:47:06 INFO 140694817969984] #quality_metric: host=algo-1, validation mse_objective <loss>=15.869095147824755
# [10/21/2022 20:47:06 INFO 140694817969984] #quality_metric: host=algo-1, validation mse <loss>=15.869095147824755
# [10/21/2022 20:47:06 INFO 140694817969984] #quality_metric: host=algo-1, validation absolute_loss <loss>=3.1916581696155024
# [10/21/2022 20:47:06 INFO 140694817969984] #quality_metric: host=algo-1, validation rmse <loss>=3.9836032869532523
# [10/21/2022 20:47:06 INFO 140694817969984] #quality_metric: host=algo-1, validation r2 <loss>=0.4635006141808501
# [10/21/2022 20:47:06 INFO 140694817969984] #quality_metric: host=algo-1, validation mae <loss>=3.1916581135170135
# [10/21/2022 20:47:06 INFO 140694817969984] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 1, "l1": 0.0, "lr_scheduler_step": 100, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [10/21/2022 20:47:06 INFO 140694817969984] Saved checkpoint to "/tmp/tmpkqnnjzbg/mx-mod-0000.params"
# [10/21/2022 20:47:06 INFO 140694817969984] Test data is not provided.
# #metrics {"StartTime": 1666385221.6521084, "EndTime": 1666385226.2450674, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 334.49506759643555, "count": 1, "min": 334.49506759643555, "max": 334.49506759643555}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 5.07354736328125, "count": 9, "min": 0.20813941955566406, "max": 1.2507438659667969}, "update.time": {"sum": 4107.749700546265, "count": 8, "min": 451.3998031616211, "max": 630.1634311676025}, "finalize.time": {"sum": 100.11935234069824, "count": 1, "min": 100.11935234069824, "max": 100.11935234069824}, "setuptime": {"sum": 3.9730072021484375, "count": 1, "min": 3.9730072021484375, "max": 3.9730072021484375}, "totaltime": {"sum": 4782.597780227661, "count": 1, "min": 4782.597780227661, "max": 4782.597780227661}}}
#
# 2022-10-21 20:47:28 Uploading - Uploading generated training model
# 2022-10-21 20:47:28 Completed - Training job completed
# Training seconds: 187
# Billable seconds: 78
# Managed Spot Training savings: 58.3%

# %% [markdown]
# Model artifact
